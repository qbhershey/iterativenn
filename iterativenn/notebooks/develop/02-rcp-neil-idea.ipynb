# %% [markdown]
# ![Alt text](image.png)

# %% [markdown]
# # First iteration

# %% [markdown]
# Define a function $1(x) = 1$.  I.e. the function $1$ ignores its input and always returns $1$.  Then $1(x) = 1$ for all $x$ in the domain of $1$.

# %% [markdown]
# $$
# \begin{align*}
# \begin{bmatrix}
# I                   & 0             & 0 & \cdots \\
# 0                   & I             & 0 & \cdots \\
# W_f \cdot (?) + b_f & v_f \odot (?) & 0 & \cdots \\
# W   \cdot (?)       & 0             & 0 & \cdots \\
# W_r \cdot (?) + b_r & v_r \odot (?) & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_t     \\
# c_{t-1} \\
# 0       \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t                           \\
# W_r \cdot x_t + b_r + v_r \odot c_{t-1} \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# \odot
# &
# \begin{bmatrix}
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1     \\
# c_{t-1} \\
# 0       \\
# \vdots  \\
# \end{bmatrix}
# \end{align*}
# $$

# %% [markdown]
# Which is
#
# $$
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# $$

# %% [markdown]
# # Second iteration

# %% [markdown]
# $$
# \begin{align*}
# \begin{bmatrix}
# I                   & 0             & 0 & \cdots \\
# 0                   & I             & 0 & \cdots \\
# W_f \cdot (?) + b_f & v_f \odot (?) & 0 & \cdots \\
# W   \cdot (?)       & 0             & 0 & \cdots \\
# W_r \cdot (?) + b_r & v_r \odot (?) & 0 & \cdots \\
# 0                   & 0             & \sigma(?) & 0 & 0         & 0 & \cdots \\
# 0                   & 0             & 0         & 0 & \sigma(?) & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t                           \\
# W_r \cdot x_t + b_r + v_r \odot c_{t-1} \\
# \sigma(W_f \cdot x_t + b_f + v_f \odot c_{t-1}) \\
# \sigma(W_r \cdot x_t + b_r + v_r \odot c_{t-1}) \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# \odot
# &
# \begin{bmatrix}
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# \end{align*}
# $$

# %% [markdown]
# Which is
#
# $$
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# \sigma(W_f \cdot x_t^T + b_f + v_f \odot c_{t-1}) \\
# \sigma(W_r \cdot x_t^T + b_r + v_r \odot c_{t-1}) \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# $$

# %% [markdown]
# Cleaning up the notation we have
#
# $$
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# f_t \\
# r_t \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# $$

# %% [markdown]
# # Third iteration

# %% [markdown]
# $$
# \begin{align*}
# \begin{bmatrix}
# I                   & 0             & 0 & \cdots \\
# 0                   & I             & 0 & \cdots \\
# W_f \cdot (?) + b_f & v_f \odot (?) & 0 & \cdots \\
# W   \cdot (?)       & 0             & 0 & \cdots \\
# W_r \cdot (?) + b_r & v_r \odot (?) & 0 & \cdots \\
# 0                   & 0             & \sigma(?) & 0 & 0         & 0     & 0 & \cdots \\
# 0                   & 0             & 0         & 0 & \sigma(?) & 0     & 0 & \cdots \\
# 0                   & 0             & 0         & 0 & 0         & I     & 0 & \cdots \\
# 0                   & 0             & 0         & 0 & 0         & (1-?) & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# f_t \\
# r_t \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t                           \\
# W_r \cdot x_t + b_r + v_r \odot c_{t-1} \\
# f_t \\
# r_t \\
# f_t \\
# (1-f_t) \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# \odot
# &
# \begin{bmatrix}
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# \mathbf{1}(x_1) \\
# c_{t-1} \\
# W \cdot x_t^T \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# &
# =
# &
# \begin{bmatrix}
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# \mathbf{1}(?) & 0 & \cdots \\
# 0 & I & 0 & 0 & 0 & 0 & \cdots \\
# 0 & 0 & 0 & I & 0 & 0 & \cdots \\
# \vdots \\
# \end{bmatrix}
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# f_t \\
# r_t \\
# 0 \\
# \vdots \\
# \end{bmatrix}
# \end{align*}
# $$

# %% [markdown]
# Cleaning up the notation we have
#
# $$
# \begin{bmatrix}
# x_t \\
# c_{t-1} \\
# W_f \cdot x_t^T + b_f + v_f \odot c_{t-1} \\
# W   \cdot x_t^T                           \\
# W_r \cdot x_t^T + b_r + v_r \odot c_{t-1} \\
# f_t \\
# r_t \\
# f_t \odot c_{t-1} \\
# (1-f_t) \odot W \cdot x_t  \\
# \vdots \\
# \end{bmatrix}
# $$

# %% [markdown]
# # Fourth iteration (left as an exercise for the reader) 😎
