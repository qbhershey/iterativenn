# %% [markdown]
# # Boilerplate code

# %% [markdown]
# ## Let called libraries be reloaded in the notebook

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

import IPython.core
IPython.core.page = print

# %% [markdown]
# ## The default the libraries are loaded we need for the code.

# %%
import torch

import numpy as np

import time

import logging
logging.basicConfig(level = logging.DEBUG)

from iterativenn.nn_modules.MaskedLinear import MaskedLinear
from iterativenn.nn_modules.SparseLinear import SparseLinear

# %% [markdown]
# # Setup models

# %%
def model_factory(cfg, device):
    model = MaskedLinear.from_description(
                                    cfg['row_sizes'],
                                    cfg['col_sizes'],
                                    cfg['block_types'],
                                    cfg['initialization_types'],
                                    cfg['trainable'],
                                    device=device
                                    )
    return model


def sparse_model_factory(model, device):
    return SparseLinear.from_MaskedLinearExact(model, transpose=False, device=device)

def sparse_model_optimized_factory(model, device):
    return SparseLinear.from_MaskedLinearExact(model, transpose=False, device=device, optimized_implementation=True)

model_setups = []
model_setups.append({'name': 'MaskedLinear', 'factory': model_factory})
model_setups.append({'name': 'SparseLinear', 'factory': sparse_model_factory})
model_setups.append({'name': 'SparseLinear_optimized', 'factory': sparse_model_optimized_factory})

# %% [markdown]
# # Parameters

# %%
use_cuda=True

# %%
# We detect if we are running on a GPU or not.  If we are, we will use it.
cuda_params = {}

if torch.cuda.is_available() and use_cuda:
    cuda_params['available'] = True
    cuda_params['current_device'] = torch.cuda.current_device()
    cuda_params['device'] = torch.cuda.device(0)
    cuda_params['device_count'] = torch.cuda.device_count()
    cuda_params['device_name'] = torch.cuda.get_device_name(0)
    devices = ['cuda:0', 'cpu']
else:
    cuda_params['available'] = False
    cuda_params['current_device'] = None
    cuda_params['device'] = 'cpu'
    cuda_params['device_count'] = None
    cuda_params['device_name'] = None
    devices = ['cpu']
logging.info(cuda_params)
logging.info(devices)
# Out:
# INFO:root:{'available': True, 'current_device': 0, 'device': <torch.cuda.device object at 0x7fb903d634c0>, 'device_count': 2, 'device_name': 'NVIDIA GeForce RTX 4090'}
# INFO:root:['cuda:0', 'cpu']

# %% [markdown]
# # Timing comparison of MaskedLinear and SparseLinear

# %%
experiments = [
    # The 2x2 case tickles some bug in CUDA...
    # {'row_sizes': [2],
    # 'col_sizes': [2],
    # 'block_types': [['D']],
    # 'initialization_types': [['G']], 
    # 'trainable': [['non-zero']]},

    # {'row_sizes': [3],
    # 'col_sizes': [4],
    # 'block_types': [['W']],
    # 'initialization_types': [['G']], 
    # 'trainable': [[1]]},

    # {'row_sizes': [3],
    # 'col_sizes': [3],
    # 'block_types': [['D']],
    # 'initialization_types': [['G']], 
    # 'trainable': [['non-zero']]},

    # {'row_sizes': [3],
    # 'col_sizes': [3],
    # 'block_types': [['D']],
    # 'initialization_types': [['G']], 
    # 'trainable': [[0]]},

    # {'row_sizes': [3],
    # 'col_sizes': [3],
    # 'block_types': [['D']],
    # 'initialization_types': [['G']], 
    # 'trainable': [[1]]},

    {'row_sizes': [1000],
    'col_sizes': [1000],
    'block_types': [['R=0.0001']],
    'initialization_types': [['G']], 
    'trainable': [['non-zero']]},

    {'row_sizes': [50, 70, 90],
    'col_sizes': [60, 80, 100],
    'block_types': [[0,       'W',     'D'],
                    ['R=0.5', 'S=5',   'Row=3'],
                    ['S=2',   'R=0.9', 'Row=1']],
    'initialization_types': [[0,            torch.ones((50, 80)), 'C=1.0'],
                             ['G',          'G=0.2,0.7',          'U'],
                             ['U=-0.5,0.5', 1,                    torch.randn(size=(90, 100))]],
    'trainable': [[0,          'non-zero', True      ],
                  ['non-zero', 'non-zero', 'non-zero'],
                  ['non-zero', 'non-zero', 'non-zero']]},

    {'row_sizes': [50, 70, 90],
    'col_sizes': [60, 80, 100],
    'block_types': [[0, 'W', 'D'],
                    ['R=0.5', 'S=5', 'Row=3'],
                    ['S=2', 'R=0.9', 'Row=1']],
    'initialization_types': [[0, torch.ones((50, 80)), 'C=1.0'],
                            ['G', 'G=0.2,0.7', 'U'],
                            ['U=-0.5,0.5', 1, torch.randn(size=(90, 100))]],
    'trainable': [[0, 'non-zero', 'non-zero'],
                ['non-zero', 'non-zero', 'non-zero'],
                ['non-zero', 'non-zero', 'non-zero']]},

    {'row_sizes': [50, 70, 90],
    'col_sizes': [60, 80, 100],
    'block_types': [[0, 'W', 'D'],
                    ['R=0.5', 'S=5', 'Row=3'],
                    ['S=2', 'R=0.9', 'Row=1']],
    'initialization_types': [[0, torch.ones((50, 80)), 'C=1.0'],
                            ['G', 'G=0.2,0.7', 'U'],
                            ['U=-0.5,0.5', 1, torch.randn(size=(90, 100))]],
    'trainable': [[0, 'non-zero', 0],
                ['non-zero', 'non-zero', 'non-zero'],
                ['non-zero', 'non-zero', 'non-zero']]},
]

# %%
def runTest(model_setups, cfg, device):
    logging.info(f'device: {device}')
    x = torch.randn(128, np.sum(cfg['col_sizes']), device=device)
    y = torch.randn(128, np.sum(cfg['row_sizes']), device=device)

    # Create the models
    for i, model_setup in enumerate(model_setups):
        # Create the model
        if i==0:
            model = model_setup['factory'](cfg, device)
            model_0 = model
        else:
            model = model_setup['factory'](model_0, device)
        model_setup['model'] = model

    # Fill in the data for each run into the model
    for i, model_setup in enumerate(model_setups):
        # Run the model and time it
        start_time = time.perf_counter()
        model_setup['output'] = model_setup['model'](x)
        model_setup['forward_time'] = time.perf_counter()-start_time

        # Compute the gradient and take a step
        optimizer = torch.optim.SGD(model_setup['model'].parameters(), lr=0.01)
        loss = torch.norm(y-model_setup['output'])

        start_time = time.perf_counter()
        loss.backward()
        model_setup['backward_time'] = time.perf_counter()-start_time

        start_time = time.perf_counter()
        optimizer.step()
        model_setup['step_time'] = time.perf_counter()-start_time

        # Now the model has been updated, and let's compare the updated models
        model_setup['after_step_output'] = model_setup['model'](x)

    # Compare the results
    logging.info('--------forward time comparison--------')
    for i, model_setup in enumerate(model_setups):
        if i==0:
            name_0 = model_setup['name']
            forward_time_0 = model_setup['forward_time']
        else:    
            name = model_setup['name']
            forward_time = model_setup['forward_time']

            logging.info(f"{name_0} forward time {forward_time_0:e}")
            logging.info(f"{name} forward time {forward_time:e}")
            logging.info(f"{name} forward time ratio {forward_time/forward_time_0:e}")

    logging.info('--------backward time comparison--------')
    for i, model_setup in enumerate(model_setups):
        if i==0:
            name_0 = model_setup['name']
            backward_time_0 = model_setup['backward_time']
        else:    
            name = model_setup['name']
            backward_time = model_setup['backward_time']

            logging.info(f"{name_0} backward time {backward_time_0:e}")
            logging.info(f"{name} backward time {backward_time:e}")
            logging.info(f"{name} backward time ratio {backward_time/backward_time_0:e}")

    logging.info('--------step time comparison--------')
    for i, model_setup in enumerate(model_setups):
        if i==0:
            name_0 = model_setup['name']
            step_time_0 = model_setup['step_time']
        else:    
            name = model_setup['name']
            step_time = model_setup['step_time']

            logging.info(f"{name_0} step time {step_time_0:e}")
            logging.info(f"{name} step time {step_time:e}")
            logging.info(f"{name} step time ratio {step_time/step_time_0:e}")

    logging.info('--------output value comparison--------')
    for i, model_setup in enumerate(model_setups):
        if i==0:
            name_0 = model_setup['name']
            output_0 = model_setup['output']
        else:    
            name = model_setup['name']
            output = model_setup['output']

            logging.info(f"{name_0} output_0 {output_0.norm():f}")
            logging.info(f"{name} output {output.norm():f}")
            logging.info(f"{name} output diff {(output_0-output).norm()/output_0.norm():f}")

    logging.info('--------after step value comparison--------')
    for i, model_setup in enumerate(model_setups):
        if i==0:
            name_0 = model_setup['name']
            after_step_output_0 = model_setup['after_step_output']
        else:    
            name = model_setup['name']
            after_step_output = model_setup['after_step_output']

            logging.info(f"{name_0} after step output_0 {after_step_output_0.norm():f}")
            logging.info(f"{name} after step output {after_step_output.norm():f}")
            logging.info(f"{name} after step output diff {(after_step_output_0-after_step_output).norm()/after_step_output_0.norm():f}")

# %%
for cfg in experiments:
    for device in devices:
        runTest(model_setups, cfg, device)
# Out:
# INFO:root:device: cuda:0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=87
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# /home/rcpaffenroth/projects/iterativenn/src/iterativenn/nn_modules/SparseLinear.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.sparse_trainable_values = torch.nn.parameter.Parameter(torch.tensor(sparse_trainable.values(), **factory_kwargs),
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=87
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 4.289063e-01
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.825229e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 4.250000e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 2.665222e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.163269e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.785601e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 2.043040e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 9.824499e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.523271e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.081231e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.452591e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.824607e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 5.439296e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.381508e-05
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 4.295874e-01
# INFO:root:SparseLinear forward time 2.344003e-03
# INFO:root:SparseLinear forward time ratio 5.456405e-03
# INFO:root:MaskedLinear forward time 4.295874e-01
# INFO:root:SparseLinear_optimized forward time 9.827199e-04
# INFO:root:SparseLinear_optimized forward time ratio 2.287590e-03
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 7.224700e-04
# INFO:root:SparseLinear backward time 3.130890e-04
# INFO:root:SparseLinear backward time ratio 4.333592e-01
# INFO:root:MaskedLinear backward time 7.224700e-04
# INFO:root:SparseLinear_optimized backward time 1.909898e-04
# INFO:root:SparseLinear_optimized backward time ratio 2.643567e-01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 3.284679e-04
# INFO:root:SparseLinear step time 7.534097e-05
# INFO:root:SparseLinear step time ratio 2.293709e-01
# INFO:root:MaskedLinear step time 3.284679e-04
# INFO:root:SparseLinear_optimized step time 7.048319e-05
# INFO:root:SparseLinear_optimized step time ratio 2.145817e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 87.119003
# INFO:root:SparseLinear output 87.119003
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 87.119003
# INFO:root:SparseLinear_optimized output 87.119003
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 86.807358
# INFO:root:SparseLinear after step output 86.807358
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 86.807358
# INFO:root:SparseLinear_optimized after step output 86.807358
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cpu
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=103
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=103
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 7.826330e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 5.482121e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 2.263761e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.587491e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.460852e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.303360e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.586690e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.297339e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.433499e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.171401e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.069410e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.073731e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.158579e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.008702e-04
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 1.284078e-03
# INFO:root:SparseLinear forward time 1.659694e-03
# INFO:root:SparseLinear forward time ratio 1.292518e+00
# INFO:root:MaskedLinear forward time 1.284078e-03
# INFO:root:SparseLinear_optimized forward time 1.084843e-03
# INFO:root:SparseLinear_optimized forward time ratio 8.448419e-01
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 1.025140e-03
# INFO:root:SparseLinear backward time 2.761290e-04
# INFO:root:SparseLinear backward time ratio 2.693573e-01
# INFO:root:MaskedLinear backward time 1.025140e-03
# INFO:root:SparseLinear_optimized backward time 2.756689e-04
# INFO:root:SparseLinear_optimized backward time ratio 2.689085e-01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 1.325589e-04
# INFO:root:SparseLinear step time 5.684700e-05
# INFO:root:SparseLinear step time ratio 4.288434e-01
# INFO:root:MaskedLinear step time 1.325589e-04
# INFO:root:SparseLinear_optimized step time 5.171704e-05
# INFO:root:SparseLinear_optimized step time ratio 3.901440e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 110.395462
# INFO:root:SparseLinear output 110.395256
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 110.395462
# INFO:root:SparseLinear_optimized output 110.395256
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 110.008865
# INFO:root:SparseLinear after step output 110.008446
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 110.008865
# INFO:root:SparseLinear_optimized after step output 110.008446
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cuda:0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=17930
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=17930
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.074721e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 5.767890e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 9.488896e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 4.996406e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.193032e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.033100e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.250862e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.156579e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.119317e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.190749e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.597901e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.920813e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.068311e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 8.659298e-05
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 7.900670e-04
# INFO:root:SparseLinear forward time 1.990297e-03
# INFO:root:SparseLinear forward time ratio 2.519149e+00
# INFO:root:MaskedLinear forward time 7.900670e-04
# INFO:root:SparseLinear_optimized forward time 9.398300e-04
# INFO:root:SparseLinear_optimized forward time ratio 1.189557e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 1.935039e-04
# INFO:root:SparseLinear backward time 1.617449e-04
# INFO:root:SparseLinear backward time ratio 8.358740e-01
# INFO:root:MaskedLinear backward time 1.935039e-04
# INFO:root:SparseLinear_optimized backward time 1.623861e-04
# INFO:root:SparseLinear_optimized backward time ratio 8.391877e-01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 8.863700e-05
# INFO:root:SparseLinear step time 7.421989e-05
# INFO:root:SparseLinear step time ratio 8.373466e-01
# INFO:root:MaskedLinear step time 8.863700e-05
# INFO:root:SparseLinear_optimized step time 8.180481e-05
# INFO:root:SparseLinear_optimized step time ratio 9.229195e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1281.157837
# INFO:root:SparseLinear output 1281.157837
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1281.157837
# INFO:root:SparseLinear_optimized output 1281.157837
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1278.854614
# INFO:root:SparseLinear after step output 1278.854614
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1278.854614
# INFO:root:SparseLinear_optimized after step output 1278.854614
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cpu
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=17882
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=17882
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.110991e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.140852e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.575972e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.704812e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.513350e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.620929e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 5.419203e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 3.490597e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.011113e-03
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.281418e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.979580e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.584859e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 6.155507e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.537807e-05
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 5.967941e-04
# INFO:root:SparseLinear forward time 2.258802e-03
# INFO:root:SparseLinear forward time ratio 3.784894e+00
# INFO:root:MaskedLinear forward time 5.967941e-04
# INFO:root:SparseLinear_optimized forward time 1.952756e-03
# INFO:root:SparseLinear_optimized forward time ratio 3.272077e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 2.139632e-04
# INFO:root:SparseLinear backward time 1.656558e-03
# INFO:root:SparseLinear backward time ratio 7.742257e+00
# INFO:root:MaskedLinear backward time 2.139632e-04
# INFO:root:SparseLinear_optimized backward time 1.258059e-02
# INFO:root:SparseLinear_optimized backward time ratio 5.879793e+01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 6.729690e-05
# INFO:root:SparseLinear step time 8.230493e-05
# INFO:root:SparseLinear step time ratio 1.223012e+00
# INFO:root:MaskedLinear step time 6.729690e-05
# INFO:root:SparseLinear_optimized step time 1.106490e-04
# INFO:root:SparseLinear_optimized step time ratio 1.644192e+00
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1228.342285
# INFO:root:SparseLinear output 1228.342529
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1228.342285
# INFO:root:SparseLinear_optimized output 1228.342529
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1226.005127
# INFO:root:SparseLinear after step output 1226.005249
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1226.005127
# INFO:root:SparseLinear_optimized after step output 1226.005249
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cuda:0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12976
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12976
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.050681e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 6.472203e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.091559e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.103480e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 9.247405e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.926999e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 9.533903e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.588797e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.201483e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 9.389711e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 9.648199e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.794704e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 9.413715e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 8.737505e-05
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 3.761782e-04
# INFO:root:SparseLinear forward time 1.053463e-03
# INFO:root:SparseLinear forward time ratio 2.800436e+00
# INFO:root:MaskedLinear forward time 3.761782e-04
# INFO:root:SparseLinear_optimized forward time 9.191912e-04
# INFO:root:SparseLinear_optimized forward time ratio 2.443499e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 2.556611e-04
# INFO:root:SparseLinear backward time 1.535991e-04
# INFO:root:SparseLinear backward time ratio 6.007918e-01
# INFO:root:MaskedLinear backward time 2.556611e-04
# INFO:root:SparseLinear_optimized backward time 1.441508e-04
# INFO:root:SparseLinear_optimized backward time ratio 5.638355e-01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 1.197560e-04
# INFO:root:SparseLinear step time 7.046293e-05
# INFO:root:SparseLinear step time ratio 5.883876e-01
# INFO:root:MaskedLinear step time 1.197560e-04
# INFO:root:SparseLinear_optimized step time 7.091393e-05
# INFO:root:SparseLinear_optimized step time ratio 5.921536e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1231.788574
# INFO:root:SparseLinear output 1231.788574
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1231.788574
# INFO:root:SparseLinear_optimized output 1231.788574
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1229.878540
# INFO:root:SparseLinear after step output 1229.878540
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1229.878540
# INFO:root:SparseLinear_optimized after step output 1229.878540
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cpu
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12881
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12881
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=0
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.246552e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.060399e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 6.675969e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.549921e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.411759e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 6.483411e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.234219e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.223207e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 5.617971e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.155471e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 3.540702e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 5.421198e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.151061e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.102381e-04
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 6.012721e-04
# INFO:root:SparseLinear forward time 2.109151e-03
# INFO:root:SparseLinear forward time ratio 3.507815e+00
# INFO:root:MaskedLinear forward time 6.012721e-04
# INFO:root:SparseLinear_optimized forward time 1.475638e-03
# INFO:root:SparseLinear_optimized forward time ratio 2.454193e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 2.010588e-04
# INFO:root:SparseLinear backward time 1.214306e-03
# INFO:root:SparseLinear backward time ratio 6.039556e+00
# INFO:root:MaskedLinear backward time 2.010588e-04
# INFO:root:SparseLinear_optimized backward time 1.123024e-03
# INFO:root:SparseLinear_optimized backward time ratio 5.585551e+00
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 7.127388e-05
# INFO:root:SparseLinear step time 8.584210e-05
# INFO:root:SparseLinear step time ratio 1.204398e+00
# INFO:root:MaskedLinear step time 7.127388e-05
# INFO:root:SparseLinear_optimized step time 7.058308e-05
# INFO:root:SparseLinear_optimized step time ratio 9.903077e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1264.496948
# INFO:root:SparseLinear output 1264.496948
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1264.496948
# INFO:root:SparseLinear_optimized output 1264.496948
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1262.576416
# INFO:root:SparseLinear after step output 1262.576416
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1262.576416
# INFO:root:SparseLinear_optimized after step output 1262.576416
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cuda:0
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12832
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=50
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12832
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=50
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 9.845500e-05
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 6.576395e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.064711e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.035996e-01
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 4.386320e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 1.247451e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.009600e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.695091e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 8.360785e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.672239e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.639090e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.816800e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.708120e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.641891e-04
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 4.582328e-04
# INFO:root:SparseLinear forward time 1.052631e-01
# INFO:root:SparseLinear forward time ratio 2.297154e+02
# INFO:root:MaskedLinear forward time 4.582328e-04
# INFO:root:SparseLinear_optimized forward time 1.561119e-03
# INFO:root:SparseLinear_optimized forward time ratio 3.406825e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 2.248529e-04
# INFO:root:SparseLinear backward time 2.952451e-04
# INFO:root:SparseLinear backward time ratio 1.313059e+00
# INFO:root:MaskedLinear backward time 2.248529e-04
# INFO:root:SparseLinear_optimized backward time 1.759720e-04
# INFO:root:SparseLinear_optimized backward time ratio 7.826093e-01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 9.858515e-05
# INFO:root:SparseLinear step time 1.458640e-04
# INFO:root:SparseLinear step time ratio 1.479573e+00
# INFO:root:MaskedLinear step time 9.858515e-05
# INFO:root:SparseLinear_optimized step time 7.328810e-05
# INFO:root:SparseLinear_optimized step time ratio 7.433990e-01
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1259.729370
# INFO:root:SparseLinear output 1259.729370
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1259.729370
# INFO:root:SparseLinear_optimized output 1259.729248
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1257.703735
# INFO:root:SparseLinear after step output 1257.703735
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1257.703735
# INFO:root:SparseLinear_optimized after step output 1257.703735
# INFO:root:SparseLinear_optimized after step output diff 0.000000
# INFO:root:device: cpu
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12908
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=50
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_trainable.values())=12908
# DEBUG:iterativenn.nn_modules.SparseLinear:len(sparse_not_trainable.values())=50
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 1.202358e-04
# DEBUG:iterativenn.nn_modules.MaskedLinear:forward time 8.864701e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 7.261871e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 6.367895e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.144852e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 4.317719e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 5.903095e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 1.797406e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 6.955091e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.293141e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 2.966588e-05
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse mm 4.362608e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:sparse not trainable 1.382509e-04
# DEBUG:iterativenn.nn_modules.SparseLinear:bias 3.427383e-05
# INFO:root:--------forward time comparison--------
# INFO:root:MaskedLinear forward time 5.061529e-04
# INFO:root:SparseLinear forward time 1.955652e-03
# INFO:root:SparseLinear forward time ratio 3.863757e+00
# INFO:root:MaskedLinear forward time 5.061529e-04
# INFO:root:SparseLinear_optimized forward time 1.600543e-03
# INFO:root:SparseLinear_optimized forward time ratio 3.162173e+00
# INFO:root:--------backward time comparison--------
# INFO:root:MaskedLinear backward time 1.724649e-04
# INFO:root:SparseLinear backward time 8.777143e-03
# INFO:root:SparseLinear backward time ratio 5.089235e+01
# INFO:root:MaskedLinear backward time 1.724649e-04
# INFO:root:SparseLinear_optimized backward time 8.640276e-03
# INFO:root:SparseLinear_optimized backward time ratio 5.009876e+01
# INFO:root:--------step time comparison--------
# INFO:root:MaskedLinear step time 6.135507e-05
# INFO:root:SparseLinear step time 6.919098e-05
# INFO:root:SparseLinear step time ratio 1.127714e+00
# INFO:root:MaskedLinear step time 6.135507e-05
# INFO:root:SparseLinear_optimized step time 7.827720e-05
# INFO:root:SparseLinear_optimized step time ratio 1.275807e+00
# INFO:root:--------output value comparison--------
# INFO:root:MaskedLinear output_0 1241.741577
# INFO:root:SparseLinear output 1241.741699
# INFO:root:SparseLinear output diff 0.000000
# INFO:root:MaskedLinear output_0 1241.741577
# INFO:root:SparseLinear_optimized output 1241.741699
# INFO:root:SparseLinear_optimized output diff 0.000000
# INFO:root:--------after step value comparison--------
# INFO:root:MaskedLinear after step output_0 1239.903564
# INFO:root:SparseLinear after step output 1239.903076
# INFO:root:SparseLinear after step output diff 0.000000
# INFO:root:MaskedLinear after step output_0 1239.903564
# INFO:root:SparseLinear_optimized after step output 1239.903076
# INFO:root:SparseLinear_optimized after step output diff 0.000000
