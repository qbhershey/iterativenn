# %% [markdown]
# # An Sequential 2D version of...
#
#
# $$
# \begin{bmatrix}
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# W_1 & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & W_2 & 0   & 0   & 0   & 0   & 0   \\
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & 0   & 0   & U_1 & 0   & 0   & 0   \\
# 0   & 0   & 0   & 0   & U_2 & 0   & 0   \\
# 0   & 0   & I/2 & 0   & 0   & I/2 & 0   \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# x_1 \\
# 0 \\
# 0 \\
# x_1 \\
# 0 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# $$

# %% [markdown]
# # The details

# %% [markdown]
# $$
# \begin{bmatrix}
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# W_1 & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & W_2 & 0   & 0   & 0   & 0   & 0   \\
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & 0   & 0   & U_1 & 0   & 0   & 0   \\
# 0   & 0   & 0   & 0   & U_2 & 0   & 0   \\
# 0   & 0   & I/2 & 0   & 0   & I/2 & 0   \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\
# 0 \\
# 0 \\
# x_1 \\
# 0 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# x_1 \\
# W_1 \cdot x_1 \\
# 0 \\
# x_1 \\
# U_1 \cdot x_1 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# \begin{bmatrix}
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# W_1 & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & W_2 & 0   & 0   & 0   & 0   & 0   \\
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & 0   & 0   & U_1 & 0   & 0   & 0   \\
# 0   & 0   & 0   & 0   & U_2 & 0   & 0   \\
# 0   & 0   & I/2 & 0   & 0   & I/2 & 0   \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\
# W_1 \cdot x_1 \\
# 0 \\
# x_1 \\
# U_1 \cdot x_1 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# x_1 \\
# W_1 \cdot x_1 \\
# W_2 \cdot W_1 \cdot x_1 \\
# x_1 \\
# U_1 \cdot x_1 \\
# U_2 \cdot U_1 \cdot x_1 \\
# 0 \\
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# \begin{bmatrix}
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# W_1 & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & W_2 & 0   & 0   & 0   & 0   & 0   \\
# I   & 0   & 0   & 0   & 0   & 0   & 0   \\
# 0   & 0   & 0   & U_1 & 0   & 0   & 0   \\
# 0   & 0   & 0   & 0   & U_2 & 0   & 0   \\
# 0   & 0   & I/2 & 0   & 0   & I/2 & 0   \\
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\
# W_1 \cdot x_1 \\
# W_2 \cdot W_1 \cdot x_1 \\
# x_1 \\
# U_1 \cdot x_1 \\
# U_2 \cdot U_1 \cdot x_1 \\
# 0 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# x_1 \\
# W_1 \cdot x_1 \\
# W_2 \cdot W_1 \cdot x_1 \\
# x_1 \\
# U_1 \cdot x_1 \\
# U_2 \cdot U_1 \cdot x_1 \\
# I/2 \cdot W_2 \cdot W_1 \cdot x_1 + I/2 \cdot U_2 \cdot U_1 \cdot x_1 \\
# \end{bmatrix}
# $$
